# %%
#project is related to classification problem 

#so we first check the dataset


#then do eda on this dataset

#we will work on dataset simply by cleaning the dataset first and make it ready for fitting data into different models

#if there will be any problem with result then we will apply different stratergies to remove the problem

# %%
#we will get a problem of class imbalance

#which make it very difficult for classification result of different classes 

#means it always shows the result of bigger class.

#so basically our model never fitted exactly as we want.

#so for this problem our objective is to increase persistence of bigger class and increase recall of smaller class

#we can do this either by resampling technique or smote technique that we will discuss in our imbalance problem solutions.

# %%
#we start doing this simply-

#1. Logistic regression
#2. K-nn 
#3. SVM i.e SVC classifier
#4. decision tree
#5. random forest
#6. Naive bayes classifier - linear, binomial, polynomial 
#7. gradient boosting

#all these above results are on the basis of best parameter which we find with help of grid search cv
#at the end we examine the results

# %%
#we then get the result not as expected so we will do resampling on data and then compare all the results

# %%
#from above result we get to know about best classifier model from the above now we will choose that model for further.

# %%
#now we will start using imblearn library different methods to solve the imbalance class problem

# %%
#and at last compare all the results.

#we use classification_report to analyse.
#we use confusion_matrix
#we use score

# %%
#we get to analyze deeply on the basis of confusion matrix
#and try to find a model that suited best in terms of correct predictions.

#means which model have least   false positive and false negative.

# %%
#after this now we use MLP classifier 
#which is part of neural networking

# %%
#after this now we use tensorflow at backend and use keras model
#this is for neural networking

# %%
#comparing all the results from sklearn classifier to imblearn classifier to neural network model 
#we find the best model out of all.

#we have trained the model on the basis of data we have and test of data we have.

#now we predict the result if any new employee entry will come we can predict easily either this employee will leave or not.

# %%
'''start the project- imbalance dataset problem prediction'''
# Out:
# 'start the project- imbalance dataset problem prediction'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %%
#some eda concepts

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
#need to work on heatmap

# %%
#above means data is complete

# %%
sns.set_style('whitegrid')

# %%
#Age
sns.distplot(df['Age'],kde=False,bins=30)

# %%
#Age
sns.distplot(df['Age'],kde=False,bins=30)

# %%
#business travel
sns.countplot(x='Attrition',hue='BusinessTravel',data=df)

# %%
#department
sns.countplot(x='Attrition',hue='Department',data=df)

# %%
#distance from home
sns.distplot(df['DistanceFromHome'],kde=False,bins=30)

# %%
sns.countplot(x='Attrition',hue='DistanceFromHome',data=df,palette='RdBu_r')

# %%
#education
sns.countplot(x='Attrition',hue='Education',data=df,palette='RdBu_r')

# %%
#educational Field
sns.countplot(x='Attrition',hue='EducationField',data=df,palette='RdBu_r')

# %% [markdown]
# # i guess employeecount and employee number is no need to consider

# %%
#environment satisfaction
sns.countplot(x='Attrition',hue='EnvironmentSatisfaction',data=df,palette='RdBu_r')

# %%
#gender
sns.countplot(x='Attrition',hue='Gender',data=df,palette='RdBu_r')

# %%
#job involvement
sns.countplot(x='Attrition',hue='JobInvolvement',data=df,palette='RdBu_r')

# %%
#job level
sns.countplot(x='Attrition',hue='JobLevel',data=df,palette='RdBu_r')

# %%
#job role
sns.countplot(x='Attrition',hue='JobRole',data=df,palette='RdBu_r')

# %%
#job satisfaction
sns.countplot(x='Attrition',hue='JobSatisfaction',data=df,palette='RdBu_r')

# %%
#maritial status
sns.countplot(x='Attrition',hue='MaritalStatus',data=df,palette='RdBu_r')

# %% [markdown]
# # monthly income and monthly rate will be considered (range)

# %%
#Num companies worked
sns.countplot(x='Attrition',hue='NumCompaniesWorked',data=df,palette='RdBu_r')

# %% [markdown]
# # over 18    is not to be considered

# %%
#overtime
sns.countplot(x='Attrition',hue='OverTime',data=df,palette='RdBu_r')

# %% [markdown]
# # PercentSalaryHike to be considered (range)

# %%
#performance rating
sns.countplot(x='Attrition',hue='PerformanceRating',data=df,palette='RdBu_r')

# %%
#RelationshipSatisfaction
sns.countplot(x='Attrition',hue='RelationshipSatisfaction',data=df,palette='RdBu_r')

# %% [markdown]
# # standard hour not to be included(fixed value=80)

# %%
#stock option level
sns.countplot(x='Attrition',hue='StockOptionLevel',data=df,palette='RdBu_r')

# %% [markdown]
# # total working years(range) and training time last year (range)

# %%
#WorkLifeBalance 
sns.countplot(x='Attrition',hue='WorkLifeBalance',data=df,palette='RdBu_r')

# %% [markdown]
# # years at company, years in current role, years since last promotion, years with currManager(range)

# %%
 #box plot of EnvironmentSatisfaction and age
plt.figure(figsize=(10,7))
sns.boxplot(x='EnvironmentSatisfaction',y='Age',data=df)

# %%
#at the end we wanted some correlation type result but here we cant apply because our data is not numeric totally.

# %%
#now we can clean some data and rearrange as we wanted for fitting data into our models

# %%
#we can either choose auomatic labelling option i.e from library help
#but problem is that when we choose new data for validation there is no clue for putting which value in place of which

# %%
#so we consideres manual approach, we will do it by simply creating new column with name and then replace it with numeric values

# %% [markdown]
# # converting attrition

# %%
def converter(private):
    if private=='Yes':
        return 1
    else:
        return 0
    

df['attrition']=df['Attrition'].apply(converter)

# %% [markdown]
# # converting Business travel

# %%
#here we will first create column like aboe and inside that all values will be zero
#then after this column will be generated we assign values manually

# %%
def converter(private):
    if private=='Yes':
        return 1
    else:
        return 0
    

df['business_travel']=df['Attrition'].apply(converter)

# %%
for i in range(1470):
    if df['BusinessTravel'][i]=='Travel_Rarely':
        df['business_travel'][i]=1
        
    elif df['BusinessTravel'][i]=='Travel_Frequently':
        df['business_travel'][i]=2
        
    else:
        df['business_travel'][i]=3
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %% [markdown]
# # converting department

# %%
def converter(private):
    if private=='Yes':
        return 1
    else:
        return 0
    

df['department']=df['Attrition'].apply(converter)

# %%
for i in range(1470):
    if df['Department'][i]=='Sales':
        df['department'][i]=1
        
    elif df['Department'][i]=='Human Resources':
        df['department'][i]=2
        
    else:
        df['department'][i]=3
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# # converting educationfield

# %%
def converter(private):
    if private=='Yes':
        return 1
    else:
        return 0
    

df['education_field']=df['Attrition'].apply(converter)

# %%
for i in range(1470):
    if df['EducationField'][i]=='Life Sciences':
        df['education_field'][i]=1
        
    elif df['EducationField'][i]=='Other':
        df['education_field'][i]=2
    
    elif df['EducationField'][i]=='Medical':
        df['education_field'][i]=3
    
    elif df['EducationField'][i]=='Marketing':
        df['education_field'][i]=4
    
    elif df['EducationField'][i]=='Technical Degree':
        df['education_field'][i]=5
    
    else:
        df['education_field'][i]=6
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %% [markdown]
# # creating dummies on gender column and dropping first option

# %%
gender1=pd.get_dummies(df['Gender'],drop_first=True)

# %%
df=pd.concat([df,gender1],axis=1)

# %% [markdown]
# # converting job role

# %%
def converter(private):
    if private=='Sales Executive':
        return 1
    else:
        return 0
    

df['job_role']=df['JobRole'].apply(converter)

# %%
for i in range(1470):
    if df['JobRole'][i]=='Sales Executive':
        df['job_role'][i]=1
    elif df['JobRole'][i]=='Research Scientist':
        df['job_role'][i]=2
    elif df['JobRole'][i]=='Laboratory Technician':
        df['job_role'][i]=3
    elif df['JobRole'][i]=='Manufacturing Director':
        df['job_role'][i]=4
    elif df['JobRole'][i]=='Healthcare Representative':
        df['job_role'][i]=5
    elif df['JobRole'][i]=='Manager':
        df['job_role'][i]=6
    elif df['JobRole'][i]=='Sales Representative':
        df['job_role'][i]=7
    elif df['JobRole'][i]=='Research Director':
        df['job_role'][i]=8
    else:
        df['job_role'][i]=9
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %% [markdown]
# # converting maritial status

# %%
def converter(private):
    if private=='Single':
        return 1
    else:
        return 0
    

df['maritial_status']=df['MaritalStatus'].apply(converter)

# %%
for i in range(1470):
    if df['MaritalStatus'][i]=='Single':
        df['maritial_status'][i]=1
    elif df['MaritalStatus'][i]=='Married':
        df['maritial_status'][i]=2
    else:
        df['maritial_status'][i]=3
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %% [markdown]
# # converting overtime

# %%
def converter(private):
    if private=='Yes':
        return 1
    else:
        return 0
    

df['over_time']=df['OverTime'].apply(converter)

# %% [markdown]
# # converting over18

# %%
def converter(private):
    if private=='Y':
        return 1
    else:
        return 0
    

df['over_18']=df['Over18'].apply(converter)

# %%
#till yet everything we want to convert is converted

# %%
df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  YearsWithCurrManager attrition  business_travel  department  \
# 0  ...                     5         1                1           1
# 1  ...                     7         0                2           3
#
#    education_field Male  job_role maritial_status  over_time  over_18
# 0                1    0         1               1          1        1
# 1                1    1         2               2          0        1
#
# [2 rows x 44 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 44 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
#so take new variable now
df1=df

# %%
df2=df1.drop(['OverTime','MaritalStatus','JobRole','Attrition','Gender','Department','BusinessTravel','EducationField','Over18'],axis=1)

# %% [markdown]
# # now our required dataframe is df2

# %%
df2.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    YearsWithCurrManager  attrition  business_travel  department  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# DailyRate                   1470 non-null int64
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobSatisfaction             1470 non-null int64
# MonthlyIncome               1470 non-null int64
# MonthlyRate                 1470 non-null int64
# NumCompaniesWorked          1470 non-null int64
# PercentSalaryHike           1470 non-null int64
# PerformanceRating           1470 non-null int64
# RelationshipSatisfaction    1470 non-null int64
# ...

# %%
#%config InlineBackend.figure_format='retina'

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df2.corr())

# %%
#for upper triangle

# %%
mask= np.zeros_like(df2.corr())

mask[np.triu_indices_from(mask)]=True

plt.figure(figsize=(15,10))
sns.heatmap(df2.corr(),mask=mask,fmt='.2f',annot=True,linewidths=0.5)

# %%
df3=df2 #saving to new variable

# %%
# Create correlation matrix
corr_matrix = df3.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.75)]

to_drop2=[column for column in upper.columns if any(upper[column]<0.0005)]

print(to_drop)
print(to_drop2)
# Drop features 
#df3.drop(df3[to_drop,to_drop2], axis=1)
# Out:
# ['MonthlyIncome', 'PerformanceRating', 'TotalWorkingYears', 'YearsInCurrentRole', 'YearsWithCurrManager']
# ['PerformanceRating', 'business_travel', 'Male', 'over_time']

# %% [markdown]
# ## from results above 0.95 -     Monthly Income
# ##             above 0.75-
# ## 'MonthlyIncome, PerformanceRating,    TotalWorkingYears,YearsInCurrentRole, YearsWithCurrManager
# ##              below 0.0005 -    PerformanceRating, business_travel, Male, Over_time
# ##           below 0.00015-    business_travel

# %%
# now we start training our models

# %%
X=df3.drop('attrition',axis=1)
y=df3['attrition']
y=y.astype('str')

y[y=='0']='L'
y[y=='1']='S'

countS=0
countL=0
for i in range(1470):
    if y[i]=='L':
         countL+=1
    
    else:
        countS+=1

print('countL',countL)
print('countS',countS)
# Out:
# countL 1233
# countS 237

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=0)
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV,KFold
#logistic regression fit
clf_base=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(3,True,1)

clf_logistic=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_logistic.fit(X_train,y_train)
print(clf_logistic.score(X_test,y_test))
print(classification_report(y_test,clf_logistic.predict(X_test)))
print(confusion_matrix(y_test,clf_logistic.predict(X_test)))
# Out:
# 0.6954731457800511
#               precision    recall  f1-score   support
#
#            L       0.89      0.98      0.93       371
#            S       0.77      0.33      0.46        70
#
#    micro avg       0.88      0.88      0.88       441
#    macro avg       0.83      0.65      0.70       441
# weighted avg       0.87      0.88      0.86       441
#
# [[364   7]
#  [ 47  23]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
df4=df3.drop('EmployeeNumber',axis=1)

# %%
X1= df4.drop('attrition',axis=1)
y1=df4['attrition']

# %%
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,train_size=0.7,random_state=0)
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
#logistic regression fit
clf_base=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(3,True,1)

clf_logistic1=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_logistic1.fit(X1_train,y1_train)
print(clf_logistic1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_logistic1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_logistic1.predict(X1_test)))
# Out:
# 0.7330666888211068
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       371
#            1       0.74      0.41      0.53        70
#
#    micro avg       0.88      0.88      0.88       441
#    macro avg       0.82      0.69      0.73       441
# weighted avg       0.87      0.88      0.87       441
#
# [[361  10]
#  [ 41  29]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#resampling

from sklearn.utils import resample

df6=pd.concat([X1,y1],axis=1)
Xnew_train,X2_test,ynew_train,y2_test=train_test_split(df6.drop('attrition',axis=1),df6['attrition'],train_size=0.7)
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
df5=pd.concat([Xnew_train,ynew_train],axis=1)

# %%
df5.head(2)
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 1004   26        652                 7          3              1
# 607    49       1184                11          3              1
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 1004                        3         100               4         1
# 607                         3          43               3         3
#
#       JobSatisfaction  ...  YearsWithCurrManager  business_travel  department  \
# 1004                1  ...                     7                1           3
# 607                 4  ...                     7                1           1
#
#       education_field  Male  job_role  maritial_status  over_time  over_18  \
# 1004                2     1         3                1          0        1
# 607                 4     0         1                2          0        1
#
#       attrition
# 1004          0
# 607           1
#
# [2 rows x 34 columns]

# %%
vL=df5[df5['attrition']==1]
vS=df5[df5['attrition']==0]

# %%
vL.shape
# Out:
# (165, 34)

# %%
vS.shape
# Out:
# (864, 34)

# %%
df_minority_upsampled=resample(vS,replace=True,n_samples=866)

df_upsampled=pd.concat([vL,df_minority_upsampled])

# %%
df_upsampled.head(2)
# Out:
#      Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 607   49       1184                11          3              1
# 514   33       1076                 3          3              1
#
#      EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 607                        3          43               3         3
# 514                        1          70               3         1
#
#      JobSatisfaction  ...  YearsWithCurrManager  business_travel  department  \
# 607                4  ...                     7                1           1
# 514                1  ...                     7                2           3
#
#      education_field  Male  job_role  maritial_status  over_time  over_18  \
# 607                4     0         1                2          0        1
# 514                1     1         2                1          1        1
#
#      attrition
# 607          1
# 514          1
#
# [2 rows x 34 columns]

# %%
df_upsampled.tail(2)
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 1352   44        170                 1          4              1
# 1172   29        469                10          3              1
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 1352                        2          78               4         2
# 1172                        3          42               2         2
#
#       JobSatisfaction  ...  YearsWithCurrManager  business_travel  department  \
# 1352                1  ...                     2                1           3
# 1172                3  ...                     4                1           1
#
#       education_field  Male  job_role  maritial_status  over_time  over_18  \
# 1352                1     1         5                2          0        1
# 1172                3     1         1                1          0        1
#
#       attrition
# 1352          0
# 1172          0
#
# [2 rows x 34 columns]

# %%
X2_train=df_upsampled.drop('attrition',axis=1)

# %%
y2_train=df_upsampled['attrition']

# %%
#logistic regression fit
clf_base=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(3,True,1)

clf_logistic2=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_logistic2.fit(X2_train,y2_train)
print(clf_logistic2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_logistic2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_logistic2.predict(X2_test)))
# Out:
# 0.6776315789473685
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92       369
#            1       0.60      0.35      0.44        72
#
#    micro avg       0.85      0.85      0.85       441
#    macro avg       0.74      0.65      0.68       441
# weighted avg       0.84      0.85      0.84       441
#
# [[352  17]
#  [ 47  25]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#logistic regression with balanced class weights
clf_base=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2'],'class_weight':['balanced']}
cv=KFold(3,True,1)

clf_logistic_balanced=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_logistic_balanced.fit(X_train,y_train)
print(clf_logistic_balanced.score(X_test,y_test))
print(classification_report(y_test,clf_logistic_balanced.predict(X_test)))
print(confusion_matrix(y_test,clf_logistic_balanced.predict(X_test)))
# Out:
# 0.6915048407857183
#               precision    recall  f1-score   support
#
#            L       0.96      0.77      0.85       371
#            S       0.40      0.81      0.53        70
#
#    micro avg       0.77      0.77      0.77       441
#    macro avg       0.68      0.79      0.69       441
# weighted avg       0.87      0.77      0.80       441
#
# [[284  87]
#  [ 13  57]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#logistic regression with balanced class weights
clf_base=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2'],'class_weight':['balanced']}
cv=KFold(3,True,1)

clf_logistic_balanced1=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_logistic_balanced1.fit(X1_train,y1_train)
print(clf_logistic_balanced1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_logistic_balanced1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_logistic_balanced1.predict(X1_test)))
# Out:
# 0.7059938103960084
#               precision    recall  f1-score   support
#
#            0       0.96      0.77      0.86       371
#            1       0.41      0.84      0.55        70
#
#    micro avg       0.78      0.78      0.78       441
#    macro avg       0.69      0.81      0.71       441
# weighted avg       0.88      0.78      0.81       441
#
# [[287  84]
#  [ 11  59]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
#logistic regression with balanced class weights
clf_base=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2'],'class_weight':['balanced']}
cv=KFold(3,True,1)

clf_logistic_balanced2=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_logistic_balanced2.fit(X2_train,y2_train)
print(clf_logistic_balanced2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_logistic_balanced2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_logistic_balanced2.predict(X2_test)))
# Out:
# 0.636638286185114
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.82       369
#            1       0.34      0.69      0.45        72
#
#    micro avg       0.73      0.73      0.73       441
#    macro avg       0.63      0.71      0.64       441
# weighted avg       0.83      0.73      0.76       441
#
# [[271  98]
#  [ 22  50]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#decision tree
clf_decisiontree=DecisionTreeClassifier()


clf_decisiontree.fit(X_train,y_train)
print(clf_decisiontree.score(X_test,y_test))
print(classification_report(y_test,clf_decisiontree.predict(X_test)))
print(confusion_matrix(y_test,clf_decisiontree.predict(X_test)))
# Out:
# 0.7959183673469388
#               precision    recall  f1-score   support
#
#            L       0.87      0.89      0.88       371
#            S       0.34      0.30      0.32        70
#
#    micro avg       0.80      0.80      0.80       441
#    macro avg       0.60      0.59      0.60       441
# weighted avg       0.79      0.80      0.79       441
#
# [[330  41]
#  [ 49  21]]

# %%
#decision tree on employee remove
clf_decisiontree1=DecisionTreeClassifier()

clf_decisiontree1.fit(X1_train,y1_train)
print(clf_decisiontree1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_decisiontree1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_decisiontree1.predict(X1_test)))
# Out:
# 0.782312925170068
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       371
#            1       0.30      0.27      0.28        70
#
#    micro avg       0.78      0.78      0.78       441
#    macro avg       0.58      0.58      0.58       441
# weighted avg       0.77      0.78      0.78       441
#
# [[326  45]
#  [ 51  19]]

# %%
#decision tree on employee remove and resampled
clf_decisiontree2=DecisionTreeClassifier()

clf_decisiontree2.fit(X2_train,y2_train)
print(clf_decisiontree2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_decisiontree2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_decisiontree2.predict(X2_test)))
# Out:
# 0.6984126984126984
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       369
#            1       0.20      0.29      0.24        72
#
#    micro avg       0.70      0.70      0.70       441
#    macro avg       0.53      0.53      0.53       441
# weighted avg       0.74      0.70      0.72       441
#
# [[287  82]
#  [ 51  21]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#random forest classifier
clf_rm_forest=RandomForestClassifier()


clf_rm_forest.fit(X_train,y_train)
print(clf_rm_forest.score(X_test,y_test))
print(classification_report(y_test,clf_rm_forest.predict(X_test)))
print(confusion_matrix(y_test,clf_rm_forest.predict(X_test)))
# Out:
# 0.854875283446712
#               precision    recall  f1-score   support
#
#            L       0.86      0.99      0.92       371
#            S       0.80      0.11      0.20        70
#
#    micro avg       0.85      0.85      0.85       441
#    macro avg       0.83      0.55      0.56       441
# weighted avg       0.85      0.85      0.81       441
#
# [[369   2]
#  [ 62   8]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#random forest classifier on employee remove
clf_rm_forest1=RandomForestClassifier()

clf_rm_forest1.fit(X1_train,y1_train)
print(clf_rm_forest1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_rm_forest1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_rm_forest1.predict(X1_test)))
# Out:
# 0.8503401360544217
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       371
#            1       0.64      0.13      0.21        70
#
#    micro avg       0.85      0.85      0.85       441
#    macro avg       0.75      0.56      0.57       441
# weighted avg       0.82      0.85      0.81       441
#
# [[366   5]
#  [ 61   9]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#random forest classifier on employee remove and resampled 
clf_rm_forest2=RandomForestClassifier()

clf_rm_forest2.fit(X2_train,y2_train)
print(clf_rm_forest2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_rm_forest2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_rm_forest2.predict(X2_test)))
# Out:
# 0.8367346938775511
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       369
#            1       0.50      0.18      0.27        72
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.68      0.57      0.59       441
# weighted avg       0.80      0.84      0.80       441
#
# [[356  13]
#  [ 59  13]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#knn

# %%
from sklearn.preprocessing import StandardScaler
df5=pd.concat([X,y],axis=1)
scaler= StandardScaler()
scaler.fit(X)

#transform
scaled_features=scaler.transform(X)
df_feat=pd.DataFrame(scaled_features,columns=df5.columns[:-1])

#split data
X_2=X
y_2=y
X2_train,X2_test,y2_train,y2_test=train_test_split(X_2,y_2,test_size=0.3,random_state=101)


#apply knn 
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X2_train,y2_train)

print('KNN',knn.score(X2_test,y2_test),'\n')
print(confusion_matrix(y2_test,knn.predict(X2_test)),'\n')
print(classification_report(y2_test,knn.predict(X2_test)))
# Out:
# KNN 0.81859410430839
#
# [[353  18]
#  [ 62   8]]
#
#               precision    recall  f1-score   support
#
#            L       0.85      0.95      0.90       371
#            S       0.31      0.11      0.17        70
#
#    micro avg       0.82      0.82      0.82       441
#    macro avg       0.58      0.53      0.53       441
# weighted avg       0.76      0.82      0.78       441
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   import sys

# %%
df6=pd.concat([X1,y1],axis=1)
scaler= StandardScaler()
scaler.fit(X1)

#transform
scaled_features=scaler.transform(X1)
df_feat=pd.DataFrame(scaled_features,columns=df6.columns[:-1])

#split data
X_2=X1
y_2=y1
X2_train,X2_test,y2_train,y2_test=train_test_split(X_2,y_2,test_size=0.3,random_state=101)


#apply knn on data without employee number
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X2_train,y2_train)

print('KNN',knn.score(X2_test,y2_test),'\n')
print(confusion_matrix(y2_test,knn.predict(X2_test)),'\n')
print(classification_report(y2_test,knn.predict(X2_test)))
# Out:
# KNN 0.8321995464852607
#
# [[360  11]
#  [ 63   7]]
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91       371
#            1       0.39      0.10      0.16        70
#
#    micro avg       0.83      0.83      0.83       441
#    macro avg       0.62      0.54      0.53       441
# weighted avg       0.78      0.83      0.79       441
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.

# %%
#we can check by changing the number of neighbors
#finding error and plotting for different values

error_rate=[]

for i in range(1,40):
    knn1= KNeighborsClassifier(n_neighbors=i)
    knn1.fit(X_train,y_train)
    predictions_i= knn1.predict(X_test)
    error_rate.append(np.mean(predictions_i!=y_test))
    

#plot error vs number of neighors
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate)
plt.title('Error rate vs k-value')
plt.xlabel('k')
plt.ylabel('error_rate')
# Out:
# Text(0, 0.5, 'error_rate')

# %%
#k = 1 we find least error

# %%
from sklearn.preprocessing import StandardScaler
df5=pd.concat([X,y],axis=1)
scaler= StandardScaler()
scaler.fit(X)

#transform
scaled_features=scaler.transform(X)
df_feat=pd.DataFrame(scaled_features,columns=df5.columns[:-1])

#split data
X_2=X
y_2=y
X2_train,X2_test,y2_train,y2_test=train_test_split(X_2,y_2,test_size=0.3,random_state=101)


#apply knn 
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X2_train,y2_train)

print('KNN',knn.score(X2_test,y2_test),'\n')
print(confusion_matrix(y2_test,knn.predict(X2_test)),'\n')
print(classification_report(y2_test,knn.predict(X2_test)))
# Out:
# KNN 0.7573696145124716
#
# [[318  53]
#  [ 54  16]]
#
#               precision    recall  f1-score   support
#
#            L       0.85      0.86      0.86       371
#            S       0.23      0.23      0.23        70
#
#    micro avg       0.76      0.76      0.76       441
#    macro avg       0.54      0.54      0.54       441
# weighted avg       0.76      0.76      0.76       441
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   import sys

# %%
#we can check by changing the number of neighbors
#finding error and plotting for different values

#on removed employee number

error_rate1=[]

for i in range(1,40):
    knn1= KNeighborsClassifier(n_neighbors=i)
    knn1.fit(X1_train,y1_train)
    predictions_i1= knn1.predict(X1_test)
    error_rate1.append(np.mean(predictions_i1!=y1_test))
    

#plot error vs number of neighors
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate1)
plt.title('Error rate vs k-value')
plt.xlabel('k')
plt.ylabel('error_rate')
# Out:
# Text(0, 0.5, 'error_rate')

# %%
#k = 1

# %%
df6=pd.concat([X1,y1],axis=1)
scaler= StandardScaler()
scaler.fit(X1)

#transform
scaled_features=scaler.transform(X1)
df_feat=pd.DataFrame(scaled_features,columns=df6.columns[:-1])

#split data
X_2=X1
y_2=y1
X2_train,X2_test,y2_train,y2_test=train_test_split(X_2,y_2,test_size=0.3,random_state=101)


#apply knn on data without employee number
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X2_train,y2_train)

print('KNN',knn.score(X2_test,y2_test),'\n')
print(confusion_matrix(y2_test,knn.predict(X2_test)),'\n')
print(classification_report(y2_test,knn.predict(X2_test)))
# Out:
# KNN 0.764172335600907
#
# [[318  53]
#  [ 51  19]]
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       371
#            1       0.26      0.27      0.27        70
#
#    micro avg       0.76      0.76      0.76       441
#    macro avg       0.56      0.56      0.56       441
# weighted avg       0.77      0.76      0.77       441
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.

# %%
#SVM- SVC classifier
from sklearn.svm import SVC
clf_base=SVC()

grid={'C':10.0**np.arange(-2,3),'gamma':[0.1,1,0.1,0.01,0.001]}
cv=KFold(3,True,1)

clf_svc=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_svc.fit(X_train,y_train)
print(clf_svc.score(X_test,y_test))
print(classification_report(y_test,clf_svc.predict(X_test)))
print(confusion_matrix(y_test,clf_svc.predict(X_test)))
# Out:
# 0.4568965517241379
#               precision    recall  f1-score   support
#
#            L       0.84      1.00      0.91       371
#            S       0.00      0.00      0.00        70
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.42      0.50      0.46       441
# weighted avg       0.71      0.84      0.77       441
#
# [[371   0]
#  [ 70   0]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
#svc for removed employee Number 

clf_base=SVC()

grid={'C':10.0**np.arange(-2,3),'gamma':[0.1,1,0.1,0.01,0.001]}
cv=KFold(3,True,1)

clf_svc1=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_svc1.fit(X1_train,y1_train)
print(clf_svc1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_svc1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_svc1.predict(X1_test)))
# Out:
# 0.4568965517241379
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       371
#            1       0.00      0.00      0.00        70
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.42      0.50      0.46       441
# weighted avg       0.71      0.84      0.77       441
#
# [[371   0]
#  [ 70   0]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
#svc for removed employee Number  and resampled

clf_base=SVC()

grid={'C':10.0**np.arange(-2,3),'gamma':[0.1,1,0.1,0.01,0.001]}
cv=KFold(3,True,1)

clf_svc2=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')

clf_svc2.fit(X2_train,y2_train)
print(clf_svc2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_svc2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_svc2.predict(X2_test)))
# Out:
# 0.4568965517241379
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       371
#            1       0.00      0.00      0.00        70
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.42      0.50      0.46       441
# weighted avg       0.71      0.84      0.77       441
#
# [[371   0]
#  [ 70   0]]
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
#naive nayes

#1. Gaussian Naive bayes
from sklearn.naive_bayes import GaussianNB
clf_gaussianNB=GaussianNB()

clf_gaussianNB.fit(X_train,y_train)
print(clf_gaussianNB.score(X_test,y_test))
print(classification_report(y_test,clf_gaussianNB.predict(X_test)))
print(confusion_matrix(y_test,clf_gaussianNB.predict(X_test)))
# Out:
# 0.8027210884353742
#               precision    recall  f1-score   support
#
#            L       0.93      0.83      0.88       371
#            S       0.42      0.64      0.51        70
#
#    micro avg       0.80      0.80      0.80       441
#    macro avg       0.67      0.74      0.69       441
# weighted avg       0.85      0.80      0.82       441
#
# [[309  62]
#  [ 25  45]]

# %%
#without employee number
clf_gaussianNB1=GaussianNB()

clf_gaussianNB1.fit(X1_train,y1_train)
print(clf_gaussianNB1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_gaussianNB1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_gaussianNB1.predict(X1_test)))
# Out:
# 0.800453514739229
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88       371
#            1       0.42      0.64      0.51        70
#
#    micro avg       0.80      0.80      0.80       441
#    macro avg       0.67      0.74      0.69       441
# weighted avg       0.84      0.80      0.82       441
#
# [[308  63]
#  [ 25  45]]

# %%
#without employee number and resampled
clf_gaussianNB2=GaussianNB()

clf_gaussianNB2.fit(X2_train,y2_train)
print(clf_gaussianNB2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_gaussianNB2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_gaussianNB2.predict(X2_test)))
# Out:
# 0.780045351473923
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86       371
#            1       0.38      0.60      0.46        70
#
#    micro avg       0.78      0.78      0.78       441
#    macro avg       0.65      0.71      0.66       441
# weighted avg       0.83      0.78      0.80       441
#
# [[302  69]
#  [ 28  42]]

# %%
#2. multinomial Naive bayes
from sklearn.naive_bayes import MultinomialNB
clf_MultinomialNB=MultinomialNB()

clf_MultinomialNB.fit(X_train,y_train)
print(clf_MultinomialNB.score(X_test,y_test))
print(classification_report(y_test,clf_MultinomialNB.predict(X_test)))
print(confusion_matrix(y_test,clf_MultinomialNB.predict(X_test)))
# Out:
# 0.5306122448979592
#               precision    recall  f1-score   support
#
#            L       0.87      0.52      0.65       371
#            S       0.19      0.60      0.29        70
#
#    micro avg       0.53      0.53      0.53       441
#    macro avg       0.53      0.56      0.47       441
# weighted avg       0.76      0.53      0.59       441
#
# [[192 179]
#  [ 28  42]]

# %%
#on without employee number
clf_MultinomialNB1=MultinomialNB()

clf_MultinomialNB1.fit(X1_train,y1_train)
print(clf_MultinomialNB1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_MultinomialNB1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_MultinomialNB1.predict(X1_test)))
# Out:
# 0.5306122448979592
#               precision    recall  f1-score   support
#
#            0       0.87      0.52      0.65       371
#            1       0.19      0.60      0.29        70
#
#    micro avg       0.53      0.53      0.53       441
#    macro avg       0.53      0.56      0.47       441
# weighted avg       0.76      0.53      0.59       441
#
# [[192 179]
#  [ 28  42]]

# %%
#on without employee number and resampled
clf_MultinomialNB2=MultinomialNB()

clf_MultinomialNB2.fit(X2_train,y2_train)
print(clf_MultinomialNB2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_MultinomialNB2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_MultinomialNB2.predict(X2_test)))
# Out:
# 0.5215419501133787
#               precision    recall  f1-score   support
#
#            0       0.86      0.52      0.65       371
#            1       0.18      0.54      0.26        70
#
#    micro avg       0.52      0.52      0.52       441
#    macro avg       0.52      0.53      0.46       441
# weighted avg       0.75      0.52      0.58       441
#
# [[192 179]
#  [ 32  38]]

# %%
#3. BernoulliNB
from sklearn.naive_bayes import BernoulliNB
clf_BernoulliNB=BernoulliNB()

clf_BernoulliNB.fit(X_train,y_train)
print(clf_BernoulliNB.score(X_test,y_test))
print(classification_report(y_test,clf_BernoulliNB.predict(X_test)))
print(confusion_matrix(y_test,clf_BernoulliNB.predict(X_test)))
# Out:
# 0.8344671201814059
#               precision    recall  f1-score   support
#
#            L       0.88      0.94      0.90       371
#            S       0.47      0.30      0.37        70
#
#    micro avg       0.83      0.83      0.83       441
#    macro avg       0.67      0.62      0.64       441
# weighted avg       0.81      0.83      0.82       441
#
# [[347  24]
#  [ 49  21]]

# %%
# without employee number

clf_BernoulliNB1=BernoulliNB()

clf_BernoulliNB1.fit(X1_train,y1_train)
print(clf_BernoulliNB1.score(X1_test,y1_test))
print(classification_report(y1_test,clf_BernoulliNB1.predict(X1_test)))
print(confusion_matrix(y1_test,clf_BernoulliNB1.predict(X1_test)))
# Out:
# 0.8344671201814059
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.90       371
#            1       0.47      0.30      0.37        70
#
#    micro avg       0.83      0.83      0.83       441
#    macro avg       0.67      0.62      0.64       441
# weighted avg       0.81      0.83      0.82       441
#
# [[347  24]
#  [ 49  21]]

# %%
# without employee number and resampled

clf_BernoulliNB2=BernoulliNB()

clf_BernoulliNB2.fit(X2_train,y2_train)
print(clf_BernoulliNB2.score(X2_test,y2_test))
print(classification_report(y2_test,clf_BernoulliNB2.predict(X2_test)))
print(confusion_matrix(y2_test,clf_BernoulliNB2.predict(X2_test)))
# Out:
# 0.8321995464852607
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90       371
#            1       0.45      0.26      0.33        70
#
#    micro avg       0.83      0.83      0.83       441
#    macro avg       0.66      0.60      0.62       441
# weighted avg       0.80      0.83      0.81       441
#
# [[349  22]
#  [ 52  18]]

# %%
#last simple technique- gradient boosting

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test)

X_train_sub, X_validation_sub, y_train_sub, y_validation_sub = train_test_split(X_train_scale, y_train, random_state=0)

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
for learning_rate in learning_rates:
    gb = GradientBoostingClassifier(n_estimators=20, learning_rate = learning_rate, max_features=2, max_depth = 2, random_state = 0)
    gb.fit(X_train_sub, y_train_sub)
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb.score(X_train_sub, y_train_sub)))
    print("Accuracy score (validation): {0:.3f}".format(gb.score(X_validation_sub, y_validation_sub)))
    print()
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.838
# Accuracy score (validation): 0.837
#
# Learning rate:  0.1
# Accuracy score (training): 0.844
# Accuracy score (validation): 0.849
#
# Learning rate:  0.25
# Accuracy score (training): 0.881
# Accuracy score (validation): 0.853
#
# Learning rate:  0.5
# Accuracy score (training): 0.904
# Accuracy score (validation): 0.845
#
# Learning rate:  0.75
# Accuracy score (training): 0.901
# Accuracy score (validation): 0.798
#
# Learning rate:  1
# Accuracy score (training): 0.916
# Accuracy score (validation): 0.822
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
scaler = MinMaxScaler()
X_train_scale = scaler.fit_transform(X_train)
X_test_scale = scaler.transform(X_test)

X_train_sub, X_validation_sub, y_train_sub, y_validation_sub = train_test_split(X_train_scale, y_train, random_state=0)

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
for learning_rate in learning_rates:
    gb = GradientBoostingClassifier(n_estimators=20, learning_rate = learning_rate, max_features=2, max_depth = 2, random_state = 0)
    gb.fit(X_train_sub, y_train_sub)
    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb.score(X_train_sub, y_train_sub)))
    print("Accuracy score (validation): {0:.3f}".format(gb.score(X_validation_sub, y_validation_sub)))
    print()
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# Learning rate:  0.05
# Accuracy score (training): 0.838
# Accuracy score (validation): 0.837
#
# Learning rate:  0.1
# Accuracy score (training): 0.844
# Accuracy score (validation): 0.849
#
# Learning rate:  0.25
# Accuracy score (training): 0.881
# Accuracy score (validation): 0.853
#
# Learning rate:  0.5
# Accuracy score (training): 0.904
# Accuracy score (validation): 0.845
#
# Learning rate:  0.75
# Accuracy score (training): 0.901
# Accuracy score (validation): 0.798
#
# Learning rate:  1
# Accuracy score (training): 0.916
# Accuracy score (validation): 0.822

# %%
# we start with now imbalance learn library

# %%
#imbalance learn library
from imblearn.under_sampling import RandomUnderSampler, NearMiss

#condensed nearest neighbor
from imblearn.under_sampling import CondensedNearestNeighbour

#further models undersampling
from imblearn.under_sampling import EditedNearestNeighbours,RepeatedEditedNearestNeighbours,TomekLinks

#further models oversampling
from imblearn.over_sampling import RandomOverSampler,SMOTE

#further models that are combinaton
from imblearn.combine import SMOTEENN,SMOTETomek

# %%
models=['Random Undersampler',' Near Miss 1',' Near Miss 2','Near Miss 3','Condensed Nearest Neigbor','Edited Nearest Neighbor','Repeated ENN','Random OverSampler','Tomek Links','SMOTE','SMOTETomek','SMOTEENN']

# %%
us1=RandomUnderSampler(ratio=0.5,random_state=1)
us2=NearMiss(ratio=0.7,n_neighbors=3,n_neighbors_ver3=3,version=1,random_state=1)
us3=NearMiss(ratio=0.5,n_neighbors=3,version=2,random_state=1)
#near miss 3
us4=NearMiss(ratio=0.5,n_neighbors=3,version=3,random_state=1)
#condensed nearest neighbor
us5= CondensedNearestNeighbour(random_state=1)
#ENN
us6= EditedNearestNeighbours(n_neighbors=2,random_state=1)
#repeated ENN
us7= RepeatedEditedNearestNeighbours(n_neighbors=2,random_state=1)
#tomek link removal
us8=TomekLinks(random_state=1)
#random oversample
us9=RandomOverSampler(ratio=0.5,random_state=1)
#synthetic Minority Oversampling Technique (smote)
us10=SMOTE(ratio=0.5,k_neighbors=10,random_state=1)
#smoteTomek
us11= SMOTETomek(ratio=0.5,random_state=1)
#smoteENN
us12= SMOTEENN(ratio=0.5,random_state=1)

variables=[us1,us2,us3,us4,us5,us6,us7,us8,us9,us10,us11,us12]

# %%
list1=[]
list2=[]

# %%
for i in range(12):
        us=variables[i]
        clf_base=LogisticRegression()
        X_train_res,y_train_res= us.fit_sample(X_train,y_train)
        grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
        clf=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')
        clf.fit(X_train_res,y_train_res)
        
        print(models[i],':' ,clf.score(X_test,y_test))
        
        print(confusion_matrix(y_test,clf.predict(X_test)))
        l1=confusion_matrix(y_test,clf.predict(X_test))
        list1.append(l1)
        l2=clf.score(X_test,y_test)
        list2.append(l2)
        
        print('\n')
        
        print(classification_report(y_test,clf.predict(X_test)))
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Random Undersampler : 0.735301025600877
# [[327  44]
#  [ 25  45]]
#
#
#               precision    recall  f1-score   support
#
#            L       0.93      0.88      0.90       371
#            S       0.51      0.64      0.57        70
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.72      0.76      0.74       441
# weighted avg       0.86      0.84      0.85       441
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#  Near Miss 1 : 0.5377331420373027
# [[208 163]
#  [ 16  54]]
#
#
#               precision    recall  f1-score   support
#
# ...

# %%
sum1=[]
for i in range(12):
    sum=0
    for j in range(2):
        
        for k in range(2):
            if(j!=k):
                sum=sum+list1[i][j][k]
    sum1.append(sum)

# %%
listdown=[]
for i in range(12):
            listdown.append(list1[i][1][0])

# %%
for i in range(12):
    print(models[i],'  Score: ',list2[i])
    print('need to be less: ',listdown[i])
    print('sum of false: ',sum1[i])
    print('\n')
# Out:
# Random Undersampler   Score:  0.735301025600877
# need to be less:  25
# sum of false:  69
#
#
#  Near Miss 1   Score:  0.5377331420373027
# need to be less:  16
# sum of false:  179
#
#
#  Near Miss 2   Score:  0.6916870234658377
# need to be less:  27
# sum of false:  85
#
#
# Near Miss 3   Score:  0.7249198330770921
# need to be less:  27
# sum of false:  71
#
#
# Condensed Nearest Neigbor   Score:  0.7230015493488547
# need to be less:  24
# sum of false:  75
#
#
# Edited Nearest Neighbor   Score:  0.7336496980155305
# need to be less:  37
# sum of false:  56
#
#
# Repeated ENN   Score:  0.736012451113417
# need to be less:  33
# sum of false:  60
#
#
# Random OverSampler   Score:  0.7117647058823529
# need to be less:  45
# sum of false:  52
#
#
# Tomek Links   Score:  0.719643992371265
# need to be less:  28
# sum of false:  72
#
#
# SMOTE   Score:  0.7480658810771033
# need to be less:  30
# sum of false:  59
#
#
# SMOTETomek   Score:  0.7211018199704871
# ...

# %%
#for without employee number

# %%
for i in range(12):
        us=variables[i]
        clf_base=LogisticRegression()
        X1_train_res,y1_train_res= us.fit_sample(X1_train,y1_train)
        grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
        clf=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')
        clf.fit(X1_train_res,y1_train_res)
        
        print(models[i],':' ,clf.score(X1_test,y1_test))
        
        print(confusion_matrix(y1_test,clf.predict(X1_test)))
        l1=confusion_matrix(y1_test,clf.predict(X1_test))
        list1.append(l1)
        l2=clf.score(X1_test,y1_test)
        list2.append(l2)
        
        print('\n')
        
        print(classification_report(y1_test,clf.predict(X1_test)))
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Random Undersampler : 0.7302659349936682
# [[325  46]
#  [ 25  45]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       371
#            1       0.49      0.64      0.56        70
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.71      0.76      0.73       441
# weighted avg       0.86      0.84      0.85       441
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#  Near Miss 1 : 0.532490680335508
# [[205 166]
#  [ 16  54]]
#
#
#               precision    recall  f1-score   support
#
# ...

# %%
sum1=[]
for i in range(12):
    sum=0
    for j in range(2):
        
        for k in range(2):
            if(j!=k):
                sum=sum+list1[i][j][k]
    sum1.append(sum)

# %%
listdown=[]
for i in range(12):
            listdown.append(list1[i][1][0])

# %%
for i in range(12):
    print(models[i],'  Score: ',list2[i])
    print('need to be less: ',listdown[i])
    print('sum of false: ',sum1[i])
    print('\n')
# Out:
# Random Undersampler   Score:  0.735301025600877
# need to be less:  25
# sum of false:  69
#
#
#  Near Miss 1   Score:  0.5377331420373027
# need to be less:  16
# sum of false:  179
#
#
#  Near Miss 2   Score:  0.6916870234658377
# need to be less:  27
# sum of false:  85
#
#
# Near Miss 3   Score:  0.7249198330770921
# need to be less:  27
# sum of false:  71
#
#
# Condensed Nearest Neigbor   Score:  0.7230015493488547
# need to be less:  24
# sum of false:  75
#
#
# Edited Nearest Neighbor   Score:  0.7336496980155305
# need to be less:  37
# sum of false:  56
#
#
# Repeated ENN   Score:  0.736012451113417
# need to be less:  33
# sum of false:  60
#
#
# Random OverSampler   Score:  0.7117647058823529
# need to be less:  45
# sum of false:  52
#
#
# Tomek Links   Score:  0.719643992371265
# need to be less:  28
# sum of false:  72
#
#
# SMOTE   Score:  0.7480658810771033
# need to be less:  30
# sum of false:  59
#
#
# SMOTETomek   Score:  0.7211018199704871
# ...

# %%
#for without employee number and resampled data
for i in range(12):
        us=variables[i]
        clf_base=LogisticRegression()
        X2_train_res,y2_train_res= us.fit_sample(X2_train,y2_train)
        grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
        clf=GridSearchCV(clf_base,grid,cv=cv,n_jobs=8,scoring='f1_macro')
        clf.fit(X2_train_res,y2_train_res)
        
        print(models[i],':' ,clf.score(X2_test,y2_test))
        
        print(confusion_matrix(y2_test,clf.predict(X2_test)))
        l1=confusion_matrix(y2_test,clf.predict(X2_test))
        list1.append(l1)
        l2=clf.score(X2_test,y2_test)
        list2.append(l2)
        
        print('\n')
        
        print(classification_report(y2_test,clf.predict(X2_test)))
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Random Undersampler : 0.6564231301939059
# [[316  55]
#  [ 35  35]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88       371
#            1       0.39      0.50      0.44        70
#
#    micro avg       0.80      0.80      0.80       441
#    macro avg       0.64      0.68      0.66       441
# weighted avg       0.82      0.80      0.81       441
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#  Near Miss 1 : 0.5367789332727262
# [[224 147]
#  [ 24  46]]
#
#
#               precision    recall  f1-score   support
#
# ...

# %%
sum1=[]
for i in range(12):
    sum=0
    for j in range(2):
        
        for k in range(2):
            if(j!=k):
                sum=sum+list1[i][j][k]
    sum1.append(sum)

# %%
listdown=[]
for i in range(12):
            listdown.append(list1[i][1][0])

# %%
for i in range(12):
    print(models[i],'  Score: ',list2[i])
    print('need to be less: ',listdown[i])
    print('sum of false: ',sum1[i])
    print('\n')
# Out:
# Random Undersampler   Score:  0.735301025600877
# need to be less:  25
# sum of false:  69
#
#
#  Near Miss 1   Score:  0.5377331420373027
# need to be less:  16
# sum of false:  179
#
#
#  Near Miss 2   Score:  0.6916870234658377
# need to be less:  27
# sum of false:  85
#
#
# Near Miss 3   Score:  0.7249198330770921
# need to be less:  27
# sum of false:  71
#
#
# Condensed Nearest Neigbor   Score:  0.7230015493488547
# need to be less:  24
# sum of false:  75
#
#
# Edited Nearest Neighbor   Score:  0.7336496980155305
# need to be less:  37
# sum of false:  56
#
#
# Repeated ENN   Score:  0.736012451113417
# need to be less:  33
# sum of false:  60
#
#
# Random OverSampler   Score:  0.7117647058823529
# need to be less:  45
# sum of false:  52
#
#
# Tomek Links   Score:  0.719643992371265
# need to be less:  28
# sum of false:  72
#
#
# SMOTE   Score:  0.7480658810771033
# need to be less:  30
# sum of false:  59
#
#
# SMOTETomek   Score:  0.7211018199704871
# ...

# %%
#until now  we have applied all models, now its time for neural networking

# %%
import sys
print('{}'.format(sys.version))
# Out:
# 3.6.8 |Anaconda, Inc.| (default, Feb 21 2019, 18:30:04) [MSC v.1916 64 bit (AMD64)]

# %%
import sys
print('{}'.format(sys.version))
# Out:
# 3.6.8 |Anaconda, Inc.| (default, Feb 21 2019, 18:30:04) [MSC v.1916 64 bit (AMD64)]

# %%
#MLP classifier
from sklearn.neural_network import MLPClassifier

sc=StandardScaler()

sc.fit(X)

scaled_X=sc.transform(X)

X_train,X_test,y_train,y_test=train_test_split(scaled_X,y,train_size=0.7)

mlp=MLPClassifier()

mlp.fit(X_train,y_train)

print(classification_report(y_test,mlp.predict(X_test)))
print(confusion_matrix(y_test,mlp.predict(X_test)))
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
#               precision    recall  f1-score   support
#
#            L       0.87      0.94      0.91       366
#            S       0.54      0.33      0.41        75
#
#    micro avg       0.84      0.84      0.84       441
#    macro avg       0.71      0.64      0.66       441
# weighted avg       0.82      0.84      0.82       441
#
# [[345  21]
# ...

# %%
#on dataset remove employee number

sc1=StandardScaler()

sc1.fit(X1)

scaled_X1=sc1.transform(X1)

Xnew1_train,Xnew1_test,y_train,y_test=train_test_split(scaled_X1,y,train_size=0.7)

mlp1=MLPClassifier()

mlp1.fit(Xnew1_train,y_train)

print(classification_report(y_test,mlp1.predict(Xnew1_test)))
print(confusion_matrix(y_test,mlp1.predict(Xnew1_test)))
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   import sys
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
#               precision    recall  f1-score   support
#
#            L       0.88      0.96      0.92       371
#            S       0.58      0.31      0.41        70
#
#    micro avg       0.85      0.85      0.85       441
#    macro avg       0.73      0.64      0.66       441
# weighted avg       0.83      0.85      0.84       441
#
# ...

# %%
#artificial neural network
import keras
from keras.models import Sequential
from keras.layers import Dense # help to assign weights
# Out:
# Using TensorFlow backend.

# %%
X=df3.drop('attrition',axis=1)
y=df3['attrition']

# %%
X3_train,X3_test,y3_train,y3_test= train_test_split(X,y,train_size=0.7)

# %%
# Here we are intialising ANN
classifier = Sequential()

# We are Adding the input layer and first hidden layer
classifier.add(Dense(output_dim = 6,init ="uniform",activation="relu",input_dim=34))

# We are Adding the input layer and first hidden layer
classifier.add(Dense(output_dim = 6,init ="uniform",activation="relu",input_dim=34))

#output layer
classifier.add(Dense(output_dim=1,init ="uniform",activation="sigmoid"))

classifier.compile(optimizer="adam",loss = "binary_crossentropy",metrics=["accuracy"])

classifier.fit(X3_train,y3_train,batch_size=10,nb_epoch=100)
# Out:
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=34, units=6, kernel_initializer="uniform")`
#   """
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=34, units=6, kernel_initializer="uniform")`
#
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\acer\.conda\envs\py36_test\lib\site-packages\ipykernel_launcher.py:15: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   from ipykernel import kernelapp as app
# Epoch 1/100
# ...
